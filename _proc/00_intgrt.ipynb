# %% [raw]
# ---
# description: Performs numeric integration for a provided function over a specific
#   interval.
# output-file: intgrt.html
# title: intgrt
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(intgrt)
# Out:
# ---
#
# [source](https://github.com/rbagdazian/nbdev-intgrt/blob/master/nbdev_intgrt/intgrt.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### intgrt
#
# >      intgrt (func, lbnd:float, ubnd:float, intvl:float)
#
# This function performs a numeric integration using a simple summation approach
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | func |  | function or method representing the curve being integrated |
# | lbnd | float | lower bound of integration |
# | ubnd | float | upper bound of integration |
# | intvl | float | value to be used for 'dx' |
