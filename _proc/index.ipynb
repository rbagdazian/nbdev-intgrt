# %% [raw]
# ---
# description: a project that implements numeric integration
# title: nbdev-intgrt
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install nbdev-intgrt
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Here's an example of using [`intgrt`](https://rbagdazian.github.io/nbdev-intgrt/intgrt.html#intgrt)

# %%
import math

lbound = 0
rbound = 1
intvl = 0.0001
func = math.sqrt
result = intgrt(func,lbound,rbound,intvl)
print(result)
# Out:
# 0.6666664591970162
